# %% [markdown]
# # PROJECT: Web Scraping - Immobiliare.it

# %% [markdown]
# The aim of this project is to get an extraction of real estate data from the website Immobiliare.it (https://www.immobiliare.it/) with a python script. Also, after a process of data cleaning and exploration, to make a ML model to predict the sale/rent appartment price.

# %% [markdown]
# -----

# %% [markdown]
# Import Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt

import requests
from bs4 import BeautifulSoup

# %% [markdown]
# ## DATA SCRAPING

# %% [markdown]
# ### DATA EXTRACTION

# %% [markdown]
# To extract the real estate data from the website, I made a script with the following functions:
# 1) a first function (scraping_areas_immobiliare) that returns a list with all city area names;
# 2) a second function (scraping_immobiliare) that returns a dataframe with all real estate data based on one city area;
# 3) a third function (city_dataframe) that, using the previous ones, return a dataframe with all real estate data based on all city areas.
#
# So, after I imported the script above, I used the third function with the following parameters: the city, the ads kind (rent/sale) and the apartment type (house/room)

# %%
# import the functions contained in the script
from functions import scraping

# %%
# make a df with the imported functions
df_immobiliare_raw = scraping.city_dataframe('napoli', 'vendita', 'case')
df_immobiliare_raw
# Out:
#                                                   title    city        area  \
# 0     Appartamento via Marechiaro 24, Marechiaro, Na...  napoli  Marechiaro
# 1     Villa unifamiliare via Marechiaro, Marechiaro,...  napoli  Marechiaro
# 2           Attico discesa Gaiola 7, Marechiaro, Napoli  napoli  Marechiaro
# 3       Appartamento viale Virgilio, Marechiaro, Napoli  napoli  Marechiaro
# 4     Bilocale via Alfano a Marechiaro, Marechiaro, ...  napoli  Marechiaro
# ...                                                 ...     ...         ...
# 4096       Attico via Giosuè Carducci 1, Chiaia, Napoli  napoli      Chiaia
# 4097  Trilocale via Ferdinando Palasciano 11, Chiaia...  napoli      Chiaia
# 4098  Quadrilocale corso Vittorio Emanuele 608, Chia...  napoli      Chiaia
# 4099  Appartamento piazzetta San Carlo alle Mortelle...  napoli      Chiaia
# 4100  Appartamento piazza Giulio Rodinò, Chiaia, Napoli  napoli      Chiaia
#
#             price surface floor rooms bathrooms
# 0       € 880.000   192m²     T     5         2
# 1            None   250m²  None    5+        3+
# 2     € 1.900.000   230m²     2    5+         3
# 3            None   450m²  None    5+        3+
# 4       € 210.000    45m²     T     2         1
# ...           ...     ...   ...   ...       ...
# 4096  € 1.000.000    75m²     9    5+        3+
# 4097    € 360.000   100m²     R     3         2
# 4098      € 1.200    95m²     5     4         3
# 4099    € 590.000   160m²     2    5+         1
# 4100    € 870.000   207m²     2    5+        3+
#
# [4101 rows x 8 columns]

# %% [markdown]
# ## DATA CLEANING & DATA EXPLORATION

# %% [markdown]
# ### DATA CLEANING

# %%
df_immobiliare_clean = df_immobiliare_raw.copy()

# %%
df_immobiliare_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4101 entries, 0 to 4100
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   title      4101 non-null   object
#  1   city       4101 non-null   object
#  2   area       4101 non-null   object
#  3   price      3980 non-null   object
#  4   surface    4098 non-null   object
#  5   floor      3789 non-null   object
#  6   rooms      4036 non-null   object
#  7   bathrooms  3669 non-null   object
# dtypes: object(8)
# memory usage: 256.4+ KB

# %%
# check unique values in the last three columns
for i in df_immobiliare_clean.columns[-3:]:
    print(i, " :", df_immobiliare_clean[i].unique())
# Out:
# floor  : ['T' None '2' 'S' 'R' '1' '3' '4' '1 - 2' '5' '2 - 3' '7' '5 - 6' '6'
#  '1 - 3' '8' '10' '9' '3 - 4' 'S2' '14' '4 - 5' 'S3' '13' '11+' '11' 'S4']
# rooms  : ['5' '5+' '2' '4' '3' '1' None]
# bathrooms  : ['2' '3+' '3' '1' None]

# %%
# check unique values in the price column
print("price :", df_immobiliare_clean.price.unique())
# Out:
# price : ['€ 880.000' None '€ 1.900.000' '€ 210.000' '€ 1.050.000' '€ 650.000'
#  '€ 350.000' '€ 690.000' '€ 290.000' '€ 780.000' '€ 380.000' '€ 1.380.000'
#  '€ 1.490.000' '€ 1.150.000' '€ 89.000' '€ 2.200.000' '€ 465.000'
#  '€ 1.650.000' '€ 795.000' '€ 3.100.000' '€ 1.250.000' '€ 180.000'
#  '€ 165.000' '€ 750.000' '€ 1.200.000' '€ 1.500.000' '€ 1.080.000'
#  'da € 1.050.000,00' '€ 1.199.000' '€ 2.300.000' '€ 1.000.000'
#  '€ 2.000.000' '€ 2.600.000' '€ 1.700.000' '€ 2.700.000' '€ 495.000'
#  '€ 740.000' '€ 450.000' '€ 870.000' '€ 790.000' '€ 4.000.000'
#  '€ 750.000€ 790.000(-5,1%)' '€ 695.000' '€ 1.280.000' '€ 890.000'
#  '€ 1.350.000€ 1.500.000(-10,0%)' '€ 850.000€ 900.000(-5,6%)'
#  '€ 1.190.000' '€ 895.000' '€ 2.500.000' '€ 1.750.000' '€ 1.070.000'
#  '€ 590.000' '€ 900.000' '€ 1.370.000' '€ 420.000' '€ 500.000'
#  '€ 1.730.000' '€ 1.320.000' '€ 930.000' '€ 520.000' '€ 170.000'
#  '€ 289.000' '€ 250.000' '€ 320.000' '€ 980.000' '€ 1.790.000' '€ 215.000'
#  '€ 260.000' '€ 480.000' '€ 300.000' '€ 820.000' '€ 800.000' '€ 490.000'
#  '€ 2.900.000' '€ 730.000' '€ 550.000' '€ 1.180.000' '€ 620.000'
#  '€ 940.000' '€ 2.238.604' '€ 2.550.000' '€ 365.000' '€ 770.000'
#  '€ 645.000' '€ 220.000' '€ 2.665.875€ 3.554.500(-25,0%)'
#  '€ 1.500.000€ 1.600.000(-6,3%)' '€ 230.000€ 245.000(-6,1%)' '€ 230.000'
#  '€ 110.000' '€ 240.000' '€ 275.000' '€ 1.030.000' '€ 725.000' '€ 280.000'
#  '€ 235.000' '€ 115.000' '€ 1.450.000' '€ 700.000' '€ 270.000' '€ 400.000'
#  '€ 200.000' '€ 470.000' '€ 140.000' '€ 680.000' '€ 145.000'
#  '€ 820.000€ 890.000(-7,9%)' '€ 850.000' '€ 360.000' '€ 135.000'
#  '€ 125.000' '€ 549.000' '€ 540.000' '€ 1.300.000' '€ 185.000' '€ 205.000'
#  '€ 65.000' '€ 370.000' '€ 390.000' '€ 950.000' '€ 430.000' '€ 85.000'
#  'da € 2.238.604,00' '€ 229.000' '€ 190.000' '€ 135.000€ 150.000(-10,0%)'
#  '€ 195.000' '€ 600.000' '€ 745.000' '€ 1.800.000' '€ 610.000'
#  '€ 1.130.000' '€ 2.450.000' '€ 1.670.000€ 1.970.000(-15,2%)' '€ 160.000'
#  '€ 225.000' '€ 1.100.000' '€ 589.000' '€ 1.120.000' 'da € 550.000,00'
#  'da € 412.500,00' 'da € 2.238.603,00' '€ 530.000' '€ 335.000' '€ 635.000'
#  '€ 3.000.000' '€ 570.000' '€ 175.000' '€ 700.000€ 850.000(-17,6%)'
#  '€ 75.000' '€ 410.000' '€ 440.000' '€ 330.000€ 360.000(-8,3%)'
#  '€ 700.000€ 760.000(-7,9%)' '€ 700.000€ 820.000(-14,6%)'
#  '€ 84.000€ 89.000(-5,6%)' '€ 1.007.000' '€ 120.000' '€ 920.000'
#  '€ 396.000' '€ 142.000€ 150.000(-5,3%)' '€ 319.000' '€ 310.000'
#  '€ 130.000' '€ 720.000' '€ 98.000' '€ 580.000' '€ 395.000'
#  '€ 225.000€ 245.000(-8,2%)' '€ 325.000' '€ 650.000€ 780.000(-16,7%)'
#  '€ 739.600' '€ 359.000' '€ 270.000€ 285.000(-5,3%)' '€ 50.000'
#  'da € 105.000,00' '€ 425.000' '€ 355.000' '€ 90.000' '€ 70.000'
#  '€ 510.000' '€ 47.000' '€ 43.000' '€ 375.000' '€ 179.000' '€ 340.000'
#  '€ 199.000' '€ 215.000€ 229.000(-6,1%)' '€ 177.000' '€ 315.000'
#  '€ 139.000' '€ 80.000' '€ 1.600.000' '€ 123.000' '€ 45.000' '€ 349.000'
#  '€ 129.000' '€ 245.000' '€ 339.000' '€ 255.000' '€ 369.000' '€ 59.000'
#  '€ 35.000' '€ 155.000€ 170.000(-8,8%)' '€ 259.000' '€ 159.000'
#  '€ 299.000' '€ 150.000' '€ 40.000' '€ 329.000' '€ 265.000' '€ 295.000'
#  '€ 268.000' '€ 169.000' '€ 95.000' '€ 189.000' '€ 209.000' '€ 269.000'
#  '€ 560.000' '€ 69.000' '€ 238.000' '€ 79.000' '€ 765.000' '€ 119.000'
#  '€ 105.000' '€ 109.000' '€ 460.000' '€ 174.000' '€ 100.000' '€ 104.000'
#  '€ 107.000' '€ 429.000' '€ 281.000' '€ 69.000€ 75.000(-8,0%)' '€ 99.000'
#  '€ 330.000' '€ 670.000' '€ 33.000' '€ 49.000' '€ 118.000'
#  '€ 125.000€ 135.000(-7,4%)' '€ 53.000' '€ 445.000' 'da € 36.000,00'
#  'da € 66.000,00' 'da € 60.000,00' '€ 1.620.000' '€ 60.000' '€ 37.000'
#  '€ 89.000€ 100.000(-11,0%)' '€ 595.000€ 640.000(-7,0%)' '€ 25.000'
#  '€ 285.000' 'da € 82.500,00' '€ 148.000' '€ 82.000' '€ 52.000'
#  '€ 266.000' '€ 219.000' '€ 95.000€ 115.000(-17,4%)' '€ 149.000'
#  '€ 147.000' '€ 239.000' '€ 55.000' '€ 990.000' '€ 155.000' '€ 83.000'
#  '€ 385.000' '€ 227.000' '€ 640.000' '€ 485.000' '€ 799.000' '€ 249.000'
#  '€ 289.000€ 319.000(-9,4%)' '€ 475.000' '€ 479.000' '€ 415.000'
#  '€ 385.000€ 410.000(-6,1%)' '€ 595.000' '€ 300.000€ 320.000(-6,3%)'
#  '€ 394.000' '€ 469.000' '€ 575.000' '€ 299.000€ 320.000(-6,6%)'
#  'da € 106.500,00' '€ 320.000€ 345.000(-7,2%)' '€ 630.000' '€ 338.000'
#  '€ 585.000' '€ 345.000' '€ 350.000€ 370.000(-5,4%)' '€ 358.000'
#  '€ 525.000' 'da € 197.250,00' 'da € 742.500,00' '€ 629.000' '€ 468.000'
#  'da € 45.000,00' '€ 710.000' '€ 399.999' '€ 415.000€ 440.000(-5,7%)'
#  '€ 675.000' 'da € 263.000,00' '€ 298.000' '€ 197.250' '€ 2.100.000'
#  '€ 455.000' '€ 1.520.000' '€ 830.000€ 880.000(-5,7%)' '€ 1.980.000'
#  '€ 660.000' '€ 520.000€ 550.000(-5,5%)' '€ 520.000€ 570.000(-8,8%)'
#  '€ 500.000€ 550.000(-9,1%)' '€ 569.000' '€ 258.000'
#  '€ 218.000€ 230.000(-5,2%)' '€ 685.000' '€ 435.000' '€ 665.000'
#  '€ 650.000€ 690.000(-5,8%)' '€ 545.000' '€ 699.000'
#  '€ 229.000€ 250.000(-8,4%)' '€ 80.000€ 95.000(-15,8%)' 'da € 378.750,00'
#  '€ 350.000€ 380.000(-7,9%)' '€ 860.000' '€ 480.000€ 530.000(-9,4%)'
#  '€ 810.000' 'da € 163.125,00' 'da € 256.875,00' '€ 458.000' '€ 898.000'
#  '€ 117.000€ 130.000(-10,0%)' '€ 2.665.875' '€ 49.900'
#  '€ 85.000€ 95.000(-10,5%)' '€ 164.000' '€ 127.000' '€ 68.000'
#  '€ 60.000€ 80.000(-25,0%)' '€ 23.000' '€ 189.000€ 199.000(-5,0%)'
#  'da € 26.250,00' 'da € 48.094,00' 'da € 119.250,00' 'da € 120.000,00'
#  'da € 44.250,00' 'da € 121.500,00' 'da € 49.500,00' '€ 37.500' '€ 18.000'
#  '€ 7.000€ 9.000(-22,2%)' '€ 41.900' 'da € 105.802,50' '€ 63.000'
#  '€ 105.000€ 115.000(-8,7%)' '€ 119.250' 'da € 24.750,00' 'da € 35.000,00'
#  '€ 73.000' '€ 108.000' '€ 3.700.000' '€ 26.250' '€ 48.094' '€ 87.000'
#  '€ 198.000' '€ 188.000' '€ 248.000' '€ 112.000' '€ 72.000' '€ 88.000'
#  '€ 168.000' '€ 58.000' '€ 75.000€ 90.000(-16,7%)' '€ 64.000' '€ 15.000'
#  '€ 158.000' 'da € 67.950,00' 'da € 67.500,00' 'da € 13.773,00'
#  'da € 46.500,00' 'da € 25.875,00' 'da € 44.011,00' 'da € 29.850,00'
#  'da € 75.000,00' '€ 28.000' 'da € 42.000,00' 'da € 237.750,00'
#  'da € 59.559,00' 'da € 87.294,00' 'da € 36.562,00' 'da € 16.875,00'
#  'da € 45.600,00' 'da € 87.637,00' 'da € 97.500,00' 'da € 90.000,00'
#  '€ 24.000' '€ 138.000' '€ 29.000' '€ 149.000€ 158.000(-5,7%)' '€ 18.500'
#  'da € 59.559,12' 'da € 80.250,00' 'da € 87.637,50' 'da € 31.640,63'
#  'da € 79.412,16' 'da € 36.562,50' '€ 143.000' 'da € 65.287,50'
#  'da € 50.000,00' 'da € 31.000,00' 'da € 44.011,86' 'da € 116.015,00'
#  'da € 130.000,00' '€ 116.000' '€ 97.500' '€ 237.750' '€ 42.000'
#  '€ 36.562' '€ 46.500' '€ 29.850' '€ 99.500' 'da € 66.825,00'
#  'da € 41.599,00' 'da € 41.599,52' 'da € 36.703,00' '€ 41.599' '€ 257.000'
#  '€ 39.900' '€ 61.000' '€ 117.000' '€ 239.000€ 269.000(-11,2%)'
#  '€ 134.000' '€ 327.000' '€ 60.000€ 65.000(-7,7%)' 'da € 9.292,00'
#  'da € 37.494,00' 'da € 52.500,00' '€ 533.000' 'da € 37.494,13'
#  'da € 69.609,37' '€ 878.000' '€ 90.000€ 95.000(-5,3%)' '€ 84.000'
#  'da € 128.625,00' '€ 128.000' '€ 39.000' 'da € 29.325,00' '€ 29.325'
#  '€ 37.494' '€ 78.000' '€ 187.000' '€ 94.000' '€ 46.000' '€ 157.000'
#  '€ 114.000' '€ 133.000' '€ 107.000€ 115.000(-7,0%)' '€ 122.000'
#  'da € 11.707,00' 'da € 51.051,00' 'da € 75.937,00' 'da € 15.187,00'
#  'da € 18.425,00' 'da € 21.938,00' 'da € 37.500,00' 'da € 130.500,00'
#  'da € 16.880,00' '€ 76.000' '€ 237.000' 'da € 38.357,55' 'da € 35.235,00'
#  'da € 23.287,50' '€ 97.000' '€ 77.000' 'da € 16.880,91' 'da € 15.750,00'
#  'da € 11.707,04' 'da € 51.051,36' 'da € 18.425,95' '€ 57.900'
#  'da € 75.937,50' '€ 16.875' '€ 15.750' '€ 44.296' '€ 75.937' '€ 49.500'
#  '€ 23.287' '€ 15.187' '€ 172.000' '€ 195.000€ 210.000(-7,1%)'
#  'da € 58.125,00' 'da € 94.500,00' '€ 94.500' 'da € 87.750,00'
#  '€ 298.000€ 320.000(-6,9%)' '€ 267.000' '€ 215.000€ 230.000(-6,5%)'
#  '€ 305.000' '€ 290.000€ 350.000(-17,1%)' 'da € 33.000,00'
#  'da € 123.375,00' 'da € 37.019,00' 'da € 13.939,00' 'da € 165.000,00'
#  '€ 395.000€ 425.000(-7,1%)' 'da € 37.019,54' '€ 215.000€ 235.000(-8,5%)'
#  '€ 285.000€ 300.000(-5,0%)' 'da € 164.500,00' '€ 123.375'
#  'da € 505.000,00' '€ 378.750' '€ 87.750' 'da € 220.000,00'
#  'da € 125.724,50' '€ 77.000€ 82.000(-6,1%)' 'da € 135.375,00'
#  'da € 20.250,00' '€ 180.000€ 195.000(-7,7%)' '€ 183.450'
#  '€ 57.000€ 65.000(-12,3%)' '€ 30.000' '€ 48.000'
#  '€ 190.000€ 210.000(-9,5%)' 'da € 18.562,50' '€ 75.000€ 80.000(-6,3%)'
#  '€ 135.375' 'da € 180.500,00' '€ 20.250' '€ 124.620€ 166.160(-25,0%)'
#  '€ 103.500' '€ 72.500€ 90.000(-19,4%)' '€ 124.000'
#  '€ 35.000€ 37.000(-5,4%)' '€ 309.000' '€ 279.000'
#  '€ 135.000€ 145.000(-6,9%)' 'da € 317.250,00' '€ 93.000'
#  '€ 31.000€ 35.000(-11,4%)' '€ 140.000€ 150.000(-6,7%)' 'da € 97.275,00'
#  '€ 317.250' '€ 97.275' '€ 92.000' '€ 1.950.000' 'da € 35.437,00'
#  'da € 68.934,37' '€ 70.000€ 75.000(-6,7%)' 'da € 63.750,00'
#  'da € 48.000,00' 'da € 35.437,50' 'da € 129.700,00' '€ 79.237' '€ 60.033'
#  'da € 273.975,00' 'da € 257.250,00' 'da € 207.900,00' '€ 1.290.000'
#  'da € 65.587,00' '€ 176.000' 'da € 65.587,50' '€ 530.000€ 570.000(-7,0%)'
#  'da € 343.000,00' 'da € 277.200,00' 'da € 365.300,00' '€ 257.250'
#  '€ 273.975' '€ 207.900' '€ 65.587' '€ 235.000€ 265.000(-11,3%)'
#  '€ 270.000€ 290.000(-6,9%)' '€ 98.000€ 105.000(-6,7%)'
#  '€ 85.000€ 90.000(-5,6%)' 'da € 185.625,00' '€ 399.000' 'da € 57.000,00'
#  '€ 166.000' '€ 62.000' 'da € 16.500,00' '€ 6.000.000' 'da € 247.500,00'
#  '€ 72.900' '€ 195.000€ 220.000(-11,4%)' '€ 210.000€ 230.000(-8,7%)'
#  'da € 131.500,00' '€ 318.000' 'da € 240.000,00' 'da € 209.250,00'
#  '€ 275.000€ 299.000(-8,0%)' '€ 220.000€ 240.000(-8,3%)' '€ 182.000'
#  'da € 108.500,00' '€ 360.000€ 380.000(-5,3%)' '€ 1.350.000' '€ 130.500'
#  '€ 830.000' '€ 1.400.000' '€ 2.400.000' '€ 785.000' '€ 1.881.295'
#  '€ 995.000' 'da € 696.000,00' '€ 760.000' '€ 815.000' 'da € 71.025,00'
#  '€ 1.220.000' 'da € 928.000,00' '€ 3.200.000' '€ 615.000' '€ 2.750.000'
#  '€ 2.800.000' '€ 800.000€ 860.000(-7,0%)' 'da € 271.360,00' '€ 8.500.000'
#  '€ 1.200']

# %%
# check the rows where the surface column has None value
df_immobiliare_clean[df_immobiliare_clean['surface'].isnull()]
# Out:
#                                                   title    city  \
# 2073         Bilocale via umbria, Secondigliano, Napoli  napoli
# 2092  Bilocale da ristrutturare, quinto piano, Secon...  napoli
# 2315       Appartamento terzo piano, Ponticelli, Napoli  napoli
#
#                area      price surface floor rooms bathrooms
# 2073  Secondigliano  € 135.000    None     2     2      None
# 2092  Secondigliano  € 116.000    None  None     2         1
# 2315     Ponticelli  € 159.000    None     3    5+      None

# %% [markdown]
# From the above it emerges that it is necessary:
#
# 1) To clean data in surface column and price column:
#     - to delete symbols (€, m²), blanks, periods (.);
#     - to keep only the discounted price, where there is a discount;
#     - to replace the auction prices with the average price in the area;
# 2) To replace the None values in surface column and price column with the area average;
# 3) To change the data type of surface column and price column;
# 4) To clean data in surface, bathrooms and rooms columns:
#    - to delete rows whare there are None values;
#    - to change the columns data type.

# %%
# make a function to replace element into a column
def clean_function(col, find, replace): 
    return col.str.replace(find, replace, regex=False)

# %% [markdown]
# #### 1.To clean data in surface column and price column

# %%
# delete symbols '€' and 'm²' in surface column and price column
df_immobiliare_clean['price'] = clean_function(df_immobiliare_clean['price'],'€', '')
df_immobiliare_clean['surface'] = clean_function(df_immobiliare_clean['surface'],'m²', '')

# rename the columns adding the unit of measure
df_immobiliare_clean = df_immobiliare_clean.rename(columns={'price':'price(€)','surface':'surface(m²)'})

# %%
# make a list with auction prices row index
index_auction_prices = df_immobiliare_clean[df_immobiliare_clean['price(€)'].str.contains('da')==True].index

# replace auction price with None value to replace them with the average later
df_immobiliare_clean.loc[index_auction_prices, 'price(€)'] = None

# %%
# make a list with discounted prices row index
index_discounted_prices = df_immobiliare_clean[df_immobiliare_clean['price(€)'].str.contains('%')==True].index

# replace the discounted prices with the only discounted price
for i in list(range(0,len(index_discounted_prices))):
    df_immobiliare_clean.loc[index_discounted_prices[i], 'price(€)'] = df_immobiliare_clean.loc[index_discounted_prices[i], 'price(€)'].split()[0]

# %%
# delete periods '.' in the price column
df_immobiliare_clean['price(€)'] = clean_function(df_immobiliare_clean['price(€)'],'.', '')

# delete periods '.' in the surface column
df_immobiliare_clean['surface(m²)'] = clean_function(df_immobiliare_clean['surface(m²)'],'.', '')

# %% [markdown]
# #### 2.To replace the None values in surface column and price column with the area average

# %%
# change the data type of the not null values in price column with 'int'
df_immobiliare_clean.loc[df_immobiliare_clean[df_immobiliare_clean['price(€)'].notnull()]['price(€)'].index, 'price(€)'] = df_immobiliare_clean.loc[df_immobiliare_clean[df_immobiliare_clean['price(€)'].notnull()]['price(€)'].index, 'price(€)'].astype('int')

# replace the None values in price column with the area average
areas_unique = df_immobiliare_clean.area.unique()

for c in areas_unique:
    m = df_immobiliare_clean[(df_immobiliare_clean['area']==c) & (df_immobiliare_clean['price(€)'].notnull())]['price(€)'].mean()
    i = df_immobiliare_clean[(df_immobiliare_clean['area']==c) & (df_immobiliare_clean['price(€)'].isnull())]['price(€)'].index
    df_immobiliare_clean.loc[i,'price(€)'] = df_immobiliare_clean.loc[i,'price(€)'].fillna(m)

# check there aren't null value
df_immobiliare_clean[df_immobiliare_clean['price(€)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, city, area, price(€), surface(m²), floor, rooms, bathrooms]
# Index: []

# %%
# change the data type of the not null values in surface column with 'int'
df_immobiliare_clean.loc[df_immobiliare_clean[df_immobiliare_clean['surface(m²)'].notnull()]['surface(m²)'].index, 'surface(m²)'] = df_immobiliare_clean.loc[df_immobiliare_clean[df_immobiliare_clean['surface(m²)'].notnull()]['surface(m²)'].index, 'surface(m²)'].astype('int')

# replace the None values in surface column with the area average
for c in areas_unique:
    m = df_immobiliare_clean[(df_immobiliare_clean['area']==c) & (df_immobiliare_clean['surface(m²)'].notnull())]['surface(m²)'].mean()
    i = df_immobiliare_clean[(df_immobiliare_clean['area']==c) & (df_immobiliare_clean['surface(m²)'].isnull())]['surface(m²)'].index
    df_immobiliare_clean.loc[i,'surface(m²)'] = df_immobiliare_clean.loc[i,'surface(m²)'].fillna(m)

# check there aren't null value
df_immobiliare_clean[df_immobiliare_clean['surface(m²)'].isnull()]
# Out:
# Empty DataFrame
# Columns: [title, city, area, price(€), surface(m²), floor, rooms, bathrooms]
# Index: []

# %% [markdown]
# #### 3.To change the data type of surface column and price column

# %%
df_immobiliare_clean['surface(m²)'] = df_immobiliare_clean['surface(m²)'].astype('int')
df_immobiliare_clean['price(€)'] = df_immobiliare_clean['price(€)'].astype('int')

# %% [markdown]
# #### 4.To clean data in surface, bathrooms and rooms columns

# %%
# delete rows where there is at least one null value in surface, bathrooms and rooms columns
df_immobiliare_clean = df_immobiliare_clean.dropna(subset=['floor', 'rooms', 'bathrooms'])

# %%
df_immobiliare_clean['bathrooms'].unique()
# Out:
# array(['2', '3', '1', '3+'], dtype=object)

# %%
# replace '3+' with '4', then convert in 'int'
df_immobiliare_clean['bathrooms'] = clean_function(df_immobiliare_clean['bathrooms'],'3+', '4')
df_immobiliare_clean['bathrooms'] = df_immobiliare_clean['bathrooms'].astype('int')

# %%
df_immobiliare_clean['rooms'].unique()
# Out:
# array(['5', '5+', '2', '4', '3', '1'], dtype=object)

# %%
# replace '5+' with  '6', then convert in 'int'
df_immobiliare_clean['rooms'] = clean_function(df_immobiliare_clean['rooms'],'5+', '6')
df_immobiliare_clean['rooms'] = df_immobiliare_clean['rooms'].astype('int')

# %%
df_immobiliare_clean['floor'].unique()
# Out:
# array(['T', '2', 'S', 'R', '1', '3', '4', '1 - 2', '5', '2 - 3', '7',
#        '5 - 6', '6', '1 - 3', '8', '10', '9', '3 - 4', 'S2', '14',
#        '4 - 5', 'S3', '13', '11+', '11', 'S4'], dtype=object)

# %%
# to get values of the floors representative of a mathematical scale that goes from the lowest to the highest, replace the values as follows:

# replace 'T' with '0' 
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'T', '0')
# replace 'R' with '0.1'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'R', '0.1')
# replace 'S2' with '-2'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'S2', '-2')
# replace 'S3' with '-3'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'S3', '-3')
# replace 'S4' with '-4'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'S4', '-4')
# replace 'S' with '-1'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'S', '-1')      # insert then others S
# replace '1 - 2' with '1.5'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'1 - 2', '1.5')
# replace '1 - 3' with '2'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'1 - 3', '2')
# replace '2 - 3' with '2.5'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'2 - 3', '2.5')
# replace '3 - 4' with '3.5'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'3 - 4', '3.5')
# replace '4 - 5' with '4.5'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'4 - 5', '4.5')
# replace '5 - 6' with '5.5'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'5 - 6', '5.5')
# replace '11+' with '12'
df_immobiliare_clean['floor'] = clean_function(df_immobiliare_clean['floor'],'11+', '12')
# convert in 'float'
df_immobiliare_clean['floor'] = df_immobiliare_clean['floor'].astype('float')

# %%
df_immobiliare_clean = df_immobiliare_clean.reset_index(drop=True)

# %%
df_immobiliare = df_immobiliare_clean.copy()

# %% [markdown]
# ### DATA EXPLORATION

# %% [markdown]
# #### General info

# %%
df_immobiliare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3397 entries, 0 to 3396
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        3397 non-null   object
#  1   city         3397 non-null   object
#  2   area         3397 non-null   object
#  3   price(€)     3397 non-null   int32
#  4   surface(m²)  3397 non-null   int32
#  5   floor        3397 non-null   float64
#  6   rooms        3397 non-null   int32
#  7   bathrooms    3397 non-null   int32
# dtypes: float64(1), int32(4), object(3)
# memory usage: 159.4+ KB

# %%
df_immobiliare.describe()
# Out:
#            price(€)    surface(m²)        floor        rooms    bathrooms
# count  3.397000e+03    3397.000000  3397.000000  3397.000000  3397.000000
# mean   3.357190e+05     144.972034     2.368089     3.449220     1.513983
# std    3.535517e+05    2065.754735     2.071412     1.294922     0.672658
# min    1.200000e+03       1.000000    -4.000000     1.000000     1.000000
# 25%    1.450000e+05      70.000000     1.000000     3.000000     1.000000
# 50%    2.350000e+05      95.000000     2.000000     3.000000     1.000000
# 75%    3.950000e+05     130.000000     3.000000     4.000000     2.000000
# max    8.500000e+06  120000.000000    14.000000     6.000000     4.000000

# %% [markdown]
# We note that the minimum and maximum of the surface variable appear to be anomalous

# %% [markdown]
# #### Price Variable

# %%
# ads number for area
df_immobiliare.groupby('area')['price(€)'].describe().sort_values(by="std", ascending=False)
# Out:
#                count           mean            std       min       25%  \
# area
# Chiaia         131.0  791040.190840  963044.405039    1200.0  280000.0
# Marechiaro      26.0  910346.153846  555885.523633  165000.0  401250.0
# Posillipo      190.0  684546.531579  495953.342703   65000.0  292500.0
# Vomero         207.0  564266.927536  383131.540527   69000.0  350000.0
# Mergellina     352.0  566798.545455  338275.110196   75000.0  360000.0
# Museo           50.0  332117.520000  310551.585026   33000.0  100000.0
# Centro         220.0  272904.327273  231107.336072   35000.0  122250.0
# Arenella       227.0  410403.255507  183266.923330   59000.0  295000.0
# Fuorigrotta    211.0  263991.478673  138528.828725   60000.0  192500.0
# Traiano         48.0  214031.250000  138503.337630   80000.0  145500.0
# Soccavo        199.0  278857.427136  133613.046939   33000.0  200000.0
# Materdei       500.0  221100.000000  127769.872351   25000.0  129250.0
# Camaldoli       31.0  202869.258065  120979.554321   45000.0  117500.0
# Chiaiano        74.0  176186.081081  101201.894435   30000.0  121250.0
# Piscinola       75.0  169383.666667   89628.328700   31000.0  110000.0
# Bagnoli        130.0  210797.400000   86563.340410   35000.0  155500.0
# Secondigliano  175.0  143952.462857   84613.242164   15000.0   85000.0
# Poggioreale     47.0  152255.319149   69995.176258   45000.0  102500.0
# Ponticelli     126.0  152899.230159   66435.740092   25000.0  100500.0
# Capodichino    106.0  132723.962264   65284.663666   25000.0   87500.0
# Pianura        146.0  163577.513699   61256.404855   20250.0  130000.0
# Barra           82.0  117425.402439   53748.450999   15750.0   79250.0
# Scampia         44.0  143411.340909   43368.075264   41599.0  109500.0
#
#                     50%        75%        max
# area
# Chiaia         500000.0   890000.0  8500000.0
# Marechiaro     837500.0  1237250.0  1900000.0
# Posillipo      600000.0   865000.0  2900000.0
# Vomero         495000.0   682500.0  3000000.0
# Mergellina     520000.0   750000.0  1350000.0
# Museo          235000.0   502500.0  1620000.0
# Centro         212500.0   340000.0  1600000.0
# Arenella       390000.0   487500.0  1150000.0
# Fuorigrotta    240000.0   296500.0  1450000.0
# Traiano        192500.0   238500.0   950000.0
# Soccavo        255000.0   320000.0  1080000.0
# Materdei       217500.0   291250.0   560000.0
# Camaldoli      185000.0   248625.0   570000.0
# Chiaiano       156500.0   216250.0   650000.0
# Piscinola      148000.0   217500.0   400000.0
# Bagnoli        202500.0   267690.5   480000.0
# Secondigliano  140000.0   179500.0   550000.0
# Poggioreale    149000.0   184500.0   360000.0
# Ponticelli     152500.0   199000.0   370000.0
# Capodichino    125000.0   173750.0   350000.0
# Pianura        170000.0   190000.0   420000.0
# Barra          114500.0   142250.0   300000.0
# Scampia        150000.0   169000.0   250000.0

# %% [markdown]
# We note that in areas where real estate has a higher value, there is a strong standard deviation. The median appears to be more representative of the price value.

# %% [markdown]
# #### Surface variable

# %%
# ads number for area
df_immobiliare.groupby('area')['surface(m²)'].describe().sort_values(by="min", ascending=False)
# Out:
#                count         mean           std   min    25%    50%     75%  \
# area
# Scampia         44.0   117.522727     37.789188  57.0  94.50  114.5  130.00
# Marechiaro      26.0   167.615385    129.911378  45.0  81.00  135.0  205.50
# Piscinola       75.0    95.533333     37.660766  40.0  70.00   90.0  112.50
# Barra           82.0    92.268293     58.185113  35.0  65.00   80.0   97.75
# Camaldoli       31.0   367.161290   1509.907659  35.0  70.00   90.0  116.50
# Arenella       227.0   107.176211     37.719678  30.0  80.00  105.0  132.00
# Poggioreale     47.0    84.851064     30.438804  30.0  66.50   76.0  105.00
# Vomero         207.0   123.207729     69.983634  30.0  84.00  110.0  147.50
# Chiaiano        74.0   102.716216     53.633337  30.0  77.75   90.0  115.00
# Bagnoli        130.0    82.607692     28.341357  25.0  60.00   80.0  100.00
# Soccavo        199.0   104.482412     36.174778  25.0  85.00  100.0  120.00
# Traiano         48.0    91.875000     24.411913  25.0  75.00   90.0  107.75
# Museo           50.0   128.680000     94.498772  22.0  60.25   90.0  200.00
# Centro         220.0   109.490909     66.177807  20.0  69.25  100.0  130.00
# Posillipo      190.0   134.021053     66.998694  18.0  85.50  120.0  164.00
# Mergellina     352.0   116.000000     49.169050  18.0  69.00  110.0  160.00
# Pianura        146.0    99.712329     33.085878  15.0  80.00  100.0  120.00
# Chiaia         131.0   219.671756    562.702578  15.0  80.00  130.0  206.00
# Secondigliano  175.0    99.965714     69.647627  14.0  67.50   88.0  110.00
# Materdei       500.0    81.750000     33.352846  11.0  66.50   71.5  102.50
# Capodichino    106.0  1220.188679  11646.904935   3.0  60.00   77.5  110.00
# Fuorigrotta    211.0    89.905213     30.385938   2.0  70.00   85.0  102.00
# Ponticelli     126.0   100.261905     45.340345   1.0  75.00   99.0  120.00
#
#                     max
# area
# Scampia           240.0
# Marechiaro        675.0
# Piscinola         250.0
# Barra             450.0
# Camaldoli        8500.0
# Arenella          220.0
# Poggioreale       190.0
# Vomero            536.0
# Chiaiano          400.0
# Bagnoli           161.0
# Soccavo           400.0
# Traiano           170.0
# Museo             460.0
# Centro            600.0
# Posillipo         395.0
# Mergellina        197.0
# Pianura           215.0
# Chiaia           5900.0
# Secondigliano     550.0
# Materdei          140.0
# Capodichino    120000.0
# Fuorigrotta       263.0
# Ponticelli        435.0

# %%
# check Capodichino area that seems to have an anomalous minimum and maximum

df_immobiliare[df_immobiliare['area']=='Capodichino'].sort_values(by="surface(m²)", ascending=False)
# Out:
#                                                   title    city         area  \
# 1572  Trilocale Strada Comunale dei Cavoni 6, Capodi...  napoli  Capodichino
# 1478      Attico via dello Sputnik, Capodichino, Napoli  napoli  Capodichino
# 1554  Palazzo - Edificio via della Mongolfiera, Capo...  napoli  Capodichino
# 1517  Bilocale via Nuovo Tempio 67, Capodichino, Napoli  napoli  Capodichino
# 1483  Quadrilocale via Filippo Maria Briganti 324, C...  napoli  Capodichino
# ...                                                 ...     ...          ...
# 1526  Bilocale via Francesco De Pinedo 15, Secondigl...  napoli  Capodichino
# 1507  Monolocale Sanda Provinciale di Caserta 177, S...  napoli  Capodichino
# 1516  Monolocale via Francesco Aggello, Capodichino,...  napoli  Capodichino
# 1524  Monolocale Strada Provinciale di Caserta, Capo...  napoli  Capodichino
# 1549  Bilocale via Caserta al Bravo, Capodichino, Na...  napoli  Capodichino
#
#       price(€)  surface(m²)  floor  rooms  bathrooms
# 1572    190000       120000    0.1      3          1
# 1478    330000          385    3.5      4          1
# 1554    185532          260    1.0      6          2
# 1517    145000          215    0.0      2          1
# 1483    164000          215    0.0      4          2
# ...        ...          ...    ...    ...        ...
# 1526     41900           32    0.0      2          1
# 1507     35000           30    0.0      1          1
# 1516     37500           30    0.0      1          1
# 1524     25000           25    0.0      1          1
# 1549     80000            3    0.0      2          1
#
# [106 rows x 8 columns]

# %%
# check Camaldoli area that seems to have an anomalous maximum

df_immobiliare[df_immobiliare['area']=='Camaldoli'].sort_values(by="surface(m²)", ascending=False).head()
# Out:
#                                                   title    city       area  \
# 2563  Palazzo - Edificio via dell'Eremo 81, Camaldol...  napoli  Camaldoli
# 2549  Quadrilocale via Vicinale Agnolella 2, Camaldo...  napoli  Camaldoli
# 2558   Appartamento via Camaldolilli, Camaldoli, Napoli  napoli  Camaldoli
# 2570  Appartamento via Vicinale Reggente 41, Camaldo...  napoli  Camaldoli
# 2569  Appartamento via Vicinale Reggente 41, Camaldo...  napoli  Camaldoli
#
#       price(€)  surface(m²)  floor  rooms  bathrooms
# 2563    310822         8500    1.0      6          4
# 2549    560000          190    1.0      4          3
# 2558    570000          190    1.0      5          3
# 2570    273975          164    1.0      6          2
# 2569    257250          153    0.0      6          2

# %% [markdown]
# We note that in the Capodino area there is a strong variance, in fact the minimum and the maximum seem to be anomalous values.
# Furthermore, there seem to be some anomalous values by observing the minima (less than 3 square meters) in the areas of Capodichino, Fuorigrotta and Ponticelli.
# For the Camaldoli area we notice a property that seems anomalous (an unusually low price considering the value of the 8500m² surface).
#
# Also in this case the median seems to be more representative of the value of the surface.

# %% [markdown]
# #### Check and remove outliers

# %% [markdown]
# We observe the distribution of the price and area variables using boxplots according to the areas to identify outliers

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))
sns.boxplot(y='area', x='surface(m²)', data=df_immobiliare, ax=axs[0])
sns.boxplot(y='area', x='price(€)', data=df_immobiliare, ax=axs[1])
axs[1].ticklabel_format(style='plain', axis='x')
plt.show()

# %% [markdown]
# Delete the anomalous values identified as follows: surface greater than 400 square meters and price greater than 3.500.000 euros.

# %%
df_immobiliare = df_immobiliare[df_immobiliare['price(€)']<3500000]
df_immobiliare = df_immobiliare[df_immobiliare['surface(m²)']<400]
df_immobiliare = df_immobiliare.reset_index(drop=True)

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))
sns.boxplot(y='area', x='surface(m²)', data=df_immobiliare, ax=axs[0])
sns.boxplot(y='area', x='price(€)', data=df_immobiliare, ax=axs[1])
axs[1].ticklabel_format(style='plain', axis='x')
plt.show()

# %%
df_immobiliare.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3369 entries, 0 to 3368
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        3369 non-null   object
#  1   city         3369 non-null   object
#  2   area         3369 non-null   object
#  3   price(€)     3369 non-null   int32
#  4   surface(m²)  3369 non-null   int32
#  5   floor        3369 non-null   float64
#  6   rooms        3369 non-null   int32
#  7   bathrooms    3369 non-null   int32
# dtypes: float64(1), int32(4), object(3)
# memory usage: 158.1+ KB

# %% [markdown]
# #### Best areas for €/m² ratio

# %% [markdown]
# Ranking areas by price

# %%
fig, axs = plt.subplots(1, 2, figsize=(18, 8))
axs[0].barh('area', 'price(€)', data=df_immobiliare.groupby('area', as_index=False)['price(€)'].median().sort_values(by='price(€)', ascending=True))
axs[0].set_title('Median Price by area')
axs[1].barh('area', 'price(€)', data=df_immobiliare.groupby('area', as_index=False)['price(€)'].mean().sort_values(by='price(€)', ascending=True))
axs[1].set_title('Avg Price by area')
plt.show()

# %% [markdown]
# Ranking areas by surface

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))
axs[0].barh('area', 'surface(m²)', data=df_immobiliare.groupby('area', as_index=False)['surface(m²)'].median().sort_values(by='surface(m²)', ascending=True))
axs[0].set_title('Median Surface by area')
axs[1].barh('area', 'surface(m²)', data=df_immobiliare.groupby('area', as_index=False)['surface(m²)'].mean().sort_values(by='surface(m²)', ascending=True))
axs[1].set_title('Avg Surface by area')
plt.show()

# %% [markdown]
# Ranking areas for €/m² ratio

# %%
df_immobiliare['ratio €/m²'] = df_immobiliare['price(€)']/df_immobiliare['surface(m²)']

# %%
fig, axs = plt.subplots(1, 2, figsize=(16, 8))
axs[0].barh('area', 'ratio €/m²', data=df_immobiliare.groupby('area', as_index=False)['ratio €/m²'].median().sort_values(by='ratio €/m²', ascending=True))
axs[0].set_title('Median rapporto €/m² by area')
axs[1].barh('area', 'ratio €/m²', data=df_immobiliare.groupby('area', as_index=False)['ratio €/m²'].mean().sort_values(by='ratio €/m²', ascending=True))
axs[1].set_title('Avg ratio €/m² by area')
plt.show()

# %% [markdown]
# ## LINEAR REGRESSION MODEL

# %% [markdown]
# ### CORRELECTION ANALYSIS

# %% [markdown]
# A strong correlation of price with surface area can be seen. The latter is in turn closely correlated with the number of rooms and bathrooms, as can be expected.
# While the floor does not seem to affect the price as much as the surface area.

# %%
sns.heatmap(df_immobiliare[df_immobiliare.columns[3:]].corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')
plt.show()

# %%
sns.scatterplot(data=df_immobiliare, x='price(€)', y='surface(m²)')
plt.ticklabel_format(style='plain', axis='x')

# %% [markdown]
# By inserting the regression line in the chart, it can be seen that its slope is influenced by properties with a price higher than 1 million euros, which appear to be a minority. Observing the distribution of the €/m² ratio median, I decide to divide the df into 3 groups by creating a "Prestige" variable with the following characteristics:
# - Median €/m² from 0 to 2000 --> low
# - Median €/m² from 2001 to 4000 --> medium
# - Median €/m² from 4001 --> high
#
# Therefore, it will be necessary to continue the analysis considering the "Prestige" group to which the zones belong.

# %%
sns.regplot(data=df_immobiliare, x='price(€)', y='surface(m²)')
plt.ticklabel_format(style='plain', axis='x')

# %%
print('Houses with price higer than 1 mln euros: n.'+ str(df_immobiliare[df_immobiliare['price(€)']>1000000]['price(€)'].count()))
print('Houses with price lower than 1 mln euros: n.'+ str(df_immobiliare[df_immobiliare['price(€)']<=1000000]['price(€)'].count()))
# Out:
# Houses with price higer than 1 mln euros: n.133
# Houses with price lower than 1 mln euros: n.3236

# %%
# create a df where for each area calculate the median of the €/m² ratio on the basis of which I assign the 'prestige' variable
df_median_prezzo_metroq = df_immobiliare.groupby('area', as_index=False)['ratio €/m²'].median().sort_values(by='ratio €/m²', ascending=True)
df_median_prezzo_metroq['prestige'] = df_median_prezzo_metroq['ratio €/m²'].apply(lambda x: 'low' if x <= 2000 else ('medium' if x <= 4000 else 'high'))
df_median_prezzo_metroq
# Out:
#              area   ratio €/m² prestige
# 18        Scampia  1288.690476      low
# 2           Barra  1388.888889      low
# 16     Ponticelli  1469.565217      low
# 19  Secondigliano  1471.405229      low
# 4     Capodichino  1500.000000      low
# 13        Pianura  1635.013501      low
# 7        Chiaiano  1647.058824      low
# 14      Piscinola  1648.728814      low
# 15    Poggioreale  1666.666667      low
# 3       Camaldoli  1958.333333      low
# 21        Traiano  2098.086124   medium
# 5          Centro  2181.818182   medium
# 12          Museo  2300.000000   medium
# 10       Materdei  2500.000000   medium
# 20        Soccavo  2581.140351   medium
# 1         Bagnoli  2604.347826   medium
# 8     Fuorigrotta  2818.181818   medium
# 0        Arenella  3834.196891   medium
# 6          Chiaia  4208.592133     high
# 22         Vomero  4416.666667     high
# 17      Posillipo  4797.979798     high
# 11     Mergellina  5071.739130     high
# 9      Marechiaro  6115.384615     high

# %%
# add the'prestige' variable to df_immobilare
df_immobiliare = df_immobiliare.merge(df_median_prezzo_metroq[['area', 'prestige']], how='left', left_on='area', right_on='area')

# %%
df_immobiliare
# Out:
#                                                   title    city        area  \
# 0     Appartamento via Marechiaro 24, Marechiaro, Na...  napoli  Marechiaro
# 1           Attico discesa Gaiola 7, Marechiaro, Napoli  napoli  Marechiaro
# 2     Bilocale via Alfano a Marechiaro, Marechiaro, ...  napoli  Marechiaro
# 3     Quadrilocale via Marechiaro 75, Marechiaro, Na...  napoli  Marechiaro
# 4     Bilocale via Franco Alfano 13, Marechiaro, Napoli  napoli  Marechiaro
# ...                                                 ...     ...         ...
# 3364       Attico via Giosuè Carducci 1, Chiaia, Napoli  napoli      Chiaia
# 3365  Trilocale via Ferdinando Palasciano 11, Chiaia...  napoli      Chiaia
# 3366  Quadrilocale corso Vittorio Emanuele 608, Chia...  napoli      Chiaia
# 3367  Appartamento piazzetta San Carlo alle Mortelle...  napoli      Chiaia
# 3368  Appartamento piazza Giulio Rodinò, Chiaia, Napoli  napoli      Chiaia
#
#       price(€)  surface(m²)  floor  rooms  bathrooms    ratio €/m² prestige
# 0       880000          192    0.0      5          2   4583.333333     high
# 1      1900000          230    2.0      6          3   8260.869565     high
# 2       210000           45    0.0      2          1   4666.666667     high
# 3       650000          100    2.0      4          2   6500.000000     high
# 4       350000           90    0.0      2          1   3888.888889     high
# ...        ...          ...    ...    ...        ...           ...      ...
# 3364   1000000           75    9.0      6          4  13333.333333     high
# 3365    360000          100    0.1      3          2   3600.000000     high
# 3366      1200           95    5.0      4          3     12.631579     high
# 3367    590000          160    2.0      6          1   3687.500000     high
# 3368    870000          207    2.0      6          4   4202.898551     high
#
# [3369 rows x 10 columns]

# %%
# check the number of each 'prestige' group
df_immobiliare['prestige'].value_counts()
# Out:
# prestige
# medium    1581
# low        898
# high       890
# Name: count, dtype: int64

# %% [markdown]
# ### LINEAR REGRESSION

# %% [markdown]
# We predict the price of an apartment based on the value of the surface for each 'prestige' group of areas in the city

# %%
import statsmodels.api as sm

# define the model for low prestige areas
Y_l = df_immobiliare[df_immobiliare['prestige']=='low']['price(€)']
X_l = df_immobiliare[df_immobiliare['prestige']=='low']['surface(m²)']
X_l = sm.add_constant(X_l)
model = sm.OLS(Y_l,X_l)
results_low = model.fit()

# define the model for medium prestige areas
Y_m = df_immobiliare[df_immobiliare['prestige']=='medium']['price(€)']
X_m = df_immobiliare[df_immobiliare['prestige']=='medium']['surface(m²)']
X_m = sm.add_constant(X_m)
model = sm.OLS(Y_m,X_m)
results_medium = model.fit()

# define the model for high prestige areas
Y_h = df_immobiliare[df_immobiliare['prestige']=='high']['price(€)']
X_h = df_immobiliare[df_immobiliare['prestige']=='high']['surface(m²)']
X_h = sm.add_constant(X_h)
model = sm.OLS(Y_h,X_h)
results_high = model.fit()

# %%
# price forecast low prestige areas
list_prices_l = []
list_sq_meters = [ 50, 60 , 70 , 80, 90, 100, 110, 120]
for c in list_sq_meters:
    list_prices_l.append(str(round(results_low.predict(np.array([1, c]))[0],2)))

df_pred_price = pd.DataFrame({'metriq': list_sq_meters, 'price_pred_low_area': list_prices_l})

# price forecast medium prestige areas
list_prices_m = []
for c in list_sq_meters:
    list_prices_m.append(str(round(results_medium.predict(np.array([1, c]))[0],2)))

# price forecast high prestige areas
list_prices_h = []
for c in list_sq_meters:
    list_prices_h.append(str(round(results_high.predict(np.array([1, c]))[0],2)))

df_pred_price['price_pred_medium_area'] = list_prices_m
df_pred_price['price_pred_high_area'] = list_prices_h
df_pred_price
# Out:
#    metriq price_pred_low_area price_pred_medium_area price_pred_high_area
# 0      50            94190.71              134223.34            194897.52
# 1      60           106675.67              164831.55            250840.21
# 2      70           119160.63              195439.76             306782.9
# 3      80           131645.59              226047.97             362725.6
# 4      90           144130.55              256656.18            418668.29
# 5     100           156615.51              287264.39            474610.98
# 6     110           169100.47               317872.6            530553.68
# 7     120           181585.43              348480.81            586496.37
